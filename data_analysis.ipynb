# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import timeit

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df1 = pd.read_csv('df_clear.csv')

# %%
df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
df['bedrooms'][2]
# Out:
# 2

# %%
df['floors']
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 21608    3.0
# 21609    2.0
# 21610    2.0
# 21611    2.0
# 21612    2.0
# Name: floors, Length: 21613, dtype: float64

# %%
df.bathrooms.value_counts(normalize=True)

#plot the bar graph of percentage job categories
df.bathrooms.value_counts(normalize=True).plot.barh()
plt.show()

# %%
df['long'].mean()
# Out:
# -122.21389640494083

# %%
#calculate the percentage of each education category.
df.floors.value_counts(normalize=True)

#plot the pie chart of education categories
df.floors.value_counts(normalize=True).plot.pie()
plt.show()

# %%
df.price.sort_values().tail(5)
# Out:
# 1448    5350000.0
# 4411    5570000.0
# 9254    6885000.0
# 3914    7062500.0
# 7252    7700000.0
# Name: price, dtype: float64

# %%
df.price.sort_values().head(10)
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# 2141     82500.0
# 18468    83000.0
# 3767     84000.0
# 16714    85000.0
# 10253    85000.0
# Name: price, dtype: float64

# %%
sns.histplot(df.sqft_living, kde=True)
plt.show()

# %%
sns.jointplot(data=df, x='sqft_living', y='price', kind='reg', color='g')
plt.show()

# %%
fig, ax = plt.subplots(3,2, figsize=(20, 18))
plt.suptitle('Distribution des variables catégorielles', fontsize=20)
sns.histplot(ax=ax[0,0],x='view',data=df)
sns.histplot(ax=ax[0,1],x='condition',data=df)
sns.histplot(ax=ax[1,0],x='grade',data=df)
sns.histplot(ax=ax[1,1],x='floors',data=df)
sns.histplot(ax=ax[2,0],x='bedrooms',data=df)
sns.histplot(ax=ax[2,1],x='bathrooms',data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='Count'>

# %%
for index in df:
    if index in ["sqft_living", "grade", "sqft_above", "sqft_living15", "bathrooms", "view", "bedrooms"]:
        print("price / " + index)
        plt.plot(df[index], df['price'], 'rx', markersize=4)
        plt.show()
# Out:
# price / bedrooms
# price / bathrooms
# price / sqft_living
# price / view
# price / grade
# price / sqft_above
# price / sqft_living15

# %%
plt.scatter(df.sqft_living, df.price)
plt.show()

# %% [markdown]
# Dans ce graphique on voit un beau lien entre sqft_living et le prix , avec une valeur étrange donc on s'attend à une bonne correlation
